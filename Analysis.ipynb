# %%
all_state = []

for line in open('state_crime.csv'):
    line = line.strip()
    state_data = line.split(",")
    all_state.append(state_data)

# %%
header = all_state[0]
rows = all_state[1:]

print("\nHeader:")
print(header)

print("\nNumber of data rows:")
print(len(rows))
for row in all_state[1:10]:
    print(row[0])
# Out:
# Header:
# ['State', 'Year', 'Population', 'Rates_Property_All', 'Rates_Property_Burglary', 'Rates_Property_Larceny', 'Rates_Property_Motor', 'Rates_Violent_All', 'Rates_Violent_Assault', 'Rates_Violent_Murder', 'Rates_Violent_Rape', 'Rates_Violent_Robbery', 'Totals_Property_All', 'Totals_Property_Burglary', 'Totals_Property_Larceny', 'Totals_Property_Motor', 'Totals_Violent_All', 'Totals_Violent_Assault', 'Totals_Violent_Murder', 'Totals_Violent_Rape', 'Totals_Violent_Robbery']
#
# Number of data rows:
# 3115
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama

# %%
import pandas as pd
my_data = pd.read_csv("state_crime.csv")
my_data.head()
# Out:
#      State  Year  Population  Rates_Property_All  Rates_Property_Burglary  \
# 0  Alabama  1960     3266740              1035.4                    355.9
# 1  Alabama  1961     3302000               985.5                    339.3
# 2  Alabama  1962     3358000              1067.0                    349.1
# 3  Alabama  1963     3347000              1150.9                    376.9
# 4  Alabama  1964     3407000              1358.7                    466.6
#
#    Rates_Property_Larceny  Rates_Property_Motor  Rates_Violent_All  \
# 0                   592.1                  87.3              186.6
# 1                   569.4                  76.8              168.5
# 2                   634.5                  83.4              157.3
# 3                   683.4                  90.6              182.7
# 4                   784.1                 108.0              213.1
#
#    Rates_Violent_Assault  Rates_Violent_Murder  ...  Rates_Violent_Robbery  \
# ...

# %%
my_data['Year']
# Out:
# 0       1960
# 1       1961
# 2       1962
# 3       1963
# 4       1964
#         ...
# 3110    2015
# 3111    2016
# 3112    2017
# 3113    2018
# 3114    2019
# Name: Year, Length: 3115, dtype: int64

# %%
my_data.iloc[1961]
# Out:
# State                       New York
# Year                            2006
# Population                  19306183
# Rates_Property_All            2064.5
# Rates_Property_Burglary        355.4
# Rates_Property_Larceny        1542.7
# Rates_Property_Motor           166.4
# Rates_Violent_All              435.2
# Rates_Violent_Assault          235.5
# Rates_Violent_Murder             4.8
# Rates_Violent_Rape              16.4
# Rates_Violent_Robbery          178.5
# Totals_Property_All           398577
# Totals_Property_Burglary       68617
# Totals_Property_Larceny       297827
# Totals_Property_Motor          32133
# Totals_Violent_All             84016
# Totals_Violent_Assault         45467
# Totals_Violent_Murder            922
# Totals_Violent_Rape             3168
# Totals_Violent_Robbery         34459
# Name: 1961, dtype: object

# %%
my_data['State'][1972]
# Out:
# 'New York'

# %%
my_data.iloc[1972:4]
# Out:
# Empty DataFrame
# Columns: [State, Year, Population, Rates_Property_All, Rates_Property_Burglary, Rates_Property_Larceny, Rates_Property_Motor, Rates_Violent_All, Rates_Violent_Assault, Rates_Violent_Murder, Rates_Violent_Rape, Rates_Violent_Robbery, Totals_Property_All, Totals_Property_Burglary, Totals_Property_Larceny, Totals_Property_Motor, Totals_Violent_All, Totals_Violent_Assault, Totals_Violent_Murder, Totals_Violent_Rape, Totals_Violent_Robbery]
# Index: []
#
# [0 rows x 21 columns]

# %%
my_data.loc[my_data['Population'] > 3700000]
# Out:
#           State  Year  Population  Rates_Property_All  \
# 18      Alabama  1978     3742000              3519.7
# 19      Alabama  1979     3769000              3830.5
# 20      Alabama  1980     3861466              4485.1
# 21      Alabama  1981     3916000              4428.3
# 22      Alabama  1982     3943000              4185.8
# ...         ...   ...         ...                 ...
# 3050  Wisconsin  2015     5771337              1974.0
# 3051  Wisconsin  2016     5778708              1933.3
# 3052  Wisconsin  2017     5795483              1808.3
# 3053  Wisconsin  2018     5813568              1559.9
# 3054  Wisconsin  2019     5822434              1471.4
#
#       Rates_Property_Burglary  Rates_Property_Larceny  Rates_Property_Motor  \
# 18                     1229.3                  1987.9                 302.5
# 19                     1287.3                  2223.2                 320.1
# 20                     1526.7                  2642.2                 316.2
# ...

# %%
my_data.loc[(my_data.Population > 3700000) & (my_data.Rates_Property_Burglary > 300.0)]
# Out:
#           State  Year  Population  Rates_Property_All  \
# 18      Alabama  1978     3742000              3519.7
# 19      Alabama  1979     3769000              3830.5
# 20      Alabama  1980     3861466              4485.1
# 21      Alabama  1981     3916000              4428.3
# 22      Alabama  1982     3943000              4185.8
# ...         ...   ...         ...                 ...
# 3048  Wisconsin  2013     5742713              2188.7
# 3049  Wisconsin  2014     5757564              2088.3
# 3050  Wisconsin  2015     5771337              1974.0
# 3051  Wisconsin  2016     5778708              1933.3
# 3052  Wisconsin  2017     5795483              1808.3
#
#       Rates_Property_Burglary  Rates_Property_Larceny  Rates_Property_Motor  \
# 18                     1229.3                  1987.9                 302.5
# 19                     1287.3                  2223.2                 320.1
# 20                     1526.7                  2642.2                 316.2
# ...

# %%
# How has all data changed across 2015 to 2019 in New York State
my_data.loc[(my_data.State == 'New York') & (my_data.Year > 2014) & (my_data.Year < 2020)]
# Out:
#          State  Year  Population  Rates_Property_All  Rates_Property_Burglary  \
# 1970  New York  2015    19795791              1604.0                    223.7
# 1971  New York  2016    19745289              1545.6                    201.7
# 1972  New York  2017    19849399              1514.2                    176.3
# 1973  New York  2018    19542209              1440.5                    159.3
# 1974  New York  2019    19453561              1373.3                    141.9
#
#       Rates_Property_Larceny  Rates_Property_Motor  Rates_Violent_All  \
# 1970                  1303.0                  77.4              379.7
# 1971                  1271.0                  72.9              376.2
# 1972                  1270.3                  67.6              356.7
# 1973                  1214.0                  67.2              350.5
# 1974                  1166.1                  65.3              358.6
#
# ...

# %%
my_data['Totals_Violent_Robbery_Per_Population'] = my_data['Totals_Violent_Robbery'] / my_data['Population']
my_data.columns
# Out:
# Index(['State', 'Year', 'Population', 'Rates_Property_All',
#        'Rates_Property_Burglary', 'Rates_Property_Larceny',
#        'Rates_Property_Motor', 'Rates_Violent_All', 'Rates_Violent_Assault',
#        'Rates_Violent_Murder', 'Rates_Violent_Rape', 'Rates_Violent_Robbery',
#        'Totals_Property_All', 'Totals_Property_Burglary',
#        'Totals_Property_Larceny', 'Totals_Property_Motor',
#        'Totals_Violent_All', 'Totals_Violent_Assault', 'Totals_Violent_Murder',
#        'Totals_Violent_Rape', 'Totals_Violent_Robbery',
#        'Totals_Violent_Robbery_Per_Population'],
#       dtype='object')

# %%
my_data.head()
# Out:
#      State  Year  Population  Rates_Property_All  Rates_Property_Burglary  \
# 0  Alabama  1960     3266740              1035.4                    355.9
# 1  Alabama  1961     3302000               985.5                    339.3
# 2  Alabama  1962     3358000              1067.0                    349.1
# 3  Alabama  1963     3347000              1150.9                    376.9
# 4  Alabama  1964     3407000              1358.7                    466.6
#
#    Rates_Property_Larceny  Rates_Property_Motor  Rates_Violent_All  \
# 0                   592.1                  87.3              186.6
# 1                   569.4                  76.8              168.5
# 2                   634.5                  83.4              157.3
# 3                   683.4                  90.6              182.7
# 4                   784.1                 108.0              213.1
#
#    Rates_Violent_Assault  Rates_Violent_Murder  ...  Totals_Property_All  \
# ...

# %%
my_data.Rates_Property_Burglary.describe()
# Out:
# count    3115.000000
# mean      876.532520
# std       446.531611
# min       126.300000
# 25%       535.000000
# 50%       796.600000
# 75%      1133.850000
# max      2906.700000
# Name: Rates_Property_Burglary, dtype: float64

# %%
my_data_State = my_data.loc[(my_data.State == "New York")]
#my_data_State.Rates_Property_All.value_counts()
my_data_State.Rates_Property_Burglary.describe()
# Out:
# count      55.000000
# mean      925.129091
# std       559.299524
# min       141.900000
# 25%       353.800000
# 50%      1015.000000
# 75%      1352.200000
# max      2061.600000
# Name: Rates_Property_Burglary, dtype: float64

# %%
def round_data_frame(d):
    return round(d)

my_data.Rates_Violent_All.apply(round_data_frame)
# Out:
# 0       187
# 1       168
# 2       157
# 3       183
# 4       213
#        ...
# 3110    222
# 3111    244
# 3112    238
# 3113    212
# 3114    217
# Name: Rates_Violent_All, Length: 3115, dtype: int64

# %%
# lambda functions
# lambda d: round(d, 1) : for the above function
my_data.Rates_Violent_All.apply(lambda d: round(d))
# Out:
# 0       187
# 1       168
# 2       157
# 3       183
# 4       213
#        ...
# 3110    222
# 3111    244
# 3112    238
# 3113    212
# 3114    217
# Name: Rates_Violent_All, Length: 3115, dtype: int64

# %%
# Sorting
my_data.sort_values(by='Population', ascending=False).head()
# Out:
#               State  Year  Population  Rates_Property_All  \
# 2694  United States  2019   328239523              2109.9
# 2693  United States  2018   327167434              2199.5
# 2692  United States  2017   325719178              2362.2
# 2691  United States  2016   323127513              2450.7
# 2690  United States  2015   321418820              2487.0
#
#       Rates_Property_Burglary  Rates_Property_Larceny  Rates_Property_Motor  \
# 2694                    340.5                  1549.5                 219.9
# 2693                    376.0                  1594.6                 228.9
# 2692                    430.4                  1694.4                 237.4
# 2691                    468.9                  1745.0                 236.9
# 2690                    491.4                  1775.4                 220.2
#
#       Rates_Violent_All  Rates_Violent_Assault  Rates_Violent_Murder  ...  \
# 2694              379.4                  250.2                   5.0  ...
# ...

# %%
import matplotlib.pyplot as plt

my_data.Rates_Property_All.plot(kind='hist')
plt.title('Property Crime Data')
plt.xlabel('Number of Property Crimes')
# Out:
# Text(0.5, 0, 'Number of Property Crimes')

# %%
my_data.plot(kind='scatter', x='Year', y='Rates_Property_All', figsize=(12,6), s=1)
plt.title("Title")
plt.xlabel("Year")
plt.ylabel("Property Crime Rates")
# Out:
# Text(0, 0.5, 'Property Crime Rates')

# %%
# creating new data frame to organize years and states better

new_york_data = my_data.loc[1920:1974]

# %%
new_york_data.Rates_Property_All.plot(kind='hist', x = 'Year', y = 'Rates_Property_All')
plt.title('Property Crime Data')
plt.xlabel('Number of Property Crimes')
# Out:
# Text(0.5, 0, 'Number of Property Crimes')

# %%
new_york_data.plot(kind='scatter', x='Year', y='Rates_Property_All')
plt.title("Title")
plt.xlabel("Year")
plt.ylabel("Property Crime Rates")
# Out:
# Text(0, 0.5, 'Property Crime Rates')

# %%
new_york_data.head()
# Out:
#          State  Year  Population  Rates_Property_All  Rates_Property_Burglary  \
# 1920  New York  1965    18073000              2740.3                   1015.0
# 1921  New York  1966    18258000              2995.4                   1074.2
# 1922  New York  1967    18336000              3367.2                   1195.2
# 1923  New York  1968    18113000              4035.4                   1385.3
# 1924  New York  1969    18321000              3991.8                   1356.2
#
#       Rates_Property_Larceny  Rates_Property_Motor  Rates_Violent_All  \
# 1920                  1401.8                 323.4              325.4
# 1921                  1568.7                 352.5              342.6
# 1922                  1715.1                 456.9              409.7
# 1923                  2071.1                 579.0              543.9
# 1924                  2005.7                 629.9              577.9
#
# ...

# %%
new_york_data.plot(kind='scatter', x='Year', y='Rates_Property_All')
plt.title('Rates of All Property Crimes per Year')
plt.xlabel('Year')
plt.ylabel('Rates of Property Crimes')
# Out:
# Text(0, 0.5, 'Rates of Property Crimes')

# %%
# Florida and Pennsylvannia data frames

penn_data = my_data.loc[2275:2334]
florida_data = my_data.loc[540:599]

# %%
penn_data.plot(kind='scatter', x='Year', y='Rates_Property_All')
plt.title("Pennsylvania Rates of All Property Crimes")
plt.xlabel("Year")
plt.ylabel("Property Crime Rates")
# Out:
# Text(0, 0.5, 'Property Crime Rates')

# %%
florida_data.plot(kind='scatter', x='Year', y='Totals_Violent_All')
plt.title('Florida Totals of All Violent Crimes')
plt.xlabel("Year")
plt.ylabel('Total of Violent Crime')
# Out:
# Text(0, 0.5, 'Total of Violent Crime')
