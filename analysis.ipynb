# %%
all_state = []

for line in open('state_crime.csv'):
    line = line.strip()
    state_data = line.split(",")
    all_state.append(state_data)
header = all_state[0]
rows = all_state[1:]

print("\nHeader:")
print(header)

print("\nNumber of data rows:")
print(len(rows))
for row in all_state[1:10]:
    print(row[0])

import pandas as pd
my_data = pd.read_csv("state_crime.csv")
my_data.head()

# %%
import pandas as pd
my_data = pd.read_csv("state_crime.csv")
my_data.head()
my_data['Year']
my_data.iloc[1961]
my_data.loc[my_data['Data.Population'] > 3700000].iloc[0:]
